# %% [markdown]
# # Import Modules

# %%
import tensorflow as tf
import numpy as np
import seaborn as sn
import pandas as pd
import os
from sklearn.metrics import confusion_matrix
import time
import copy
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

### Used for importing the model
import urllib.request
import tarfile
import zipfile
import sys
import os
import pickle
import random

from IPython.display import Image, display

# %% [markdown]
# # Define Key Values
# We have a lot of files we need to setup to load the model and prepare it for transfer learning. In this block we define file and folder names for pulling data from the model we're downloading/downloaded.
#
# model_url: url for the inception model freely available from google. The model will be loaded from here
# model_directory: directory which we want to put our model files at
# map_id_to_class: file that maps out the dataset ids to classes
# map_id_to_name: file that maps out the dataset id to class names
#
# The second block of strings are names that are already defined in the model. Here we're defining them so we can later access those tensors for future use, such as connecting a layer to a newly made layer

# %%
# Define Model
model_url = "http://download.tensorflow.org/models/image/imagenet/inception-2015-12-05.tgz"
model_directory1 = "inception"
map_id_to_class  = "imagenet_2012_challenge_label_map_proto.pbtxt"
map_id_to_name = "imagenet_synset_to_human_label_map.txt"
map_graph_def = "classify_image_graph_def.pb"

#tensors used later for transfer learning
bottleneck_tensor_name = 'pool_3:0'
jpeg_tensor_name = 'DecodeJpeg/contents:0'
resized_input_tensor_name = 'ResizeBilinear:0'
softmax_tensor_name = "softmax:0"
softmax_tensor_logits_name = 'softmax/logits:0'

# %% [markdown]
# # Data
# Here we define the folder the data is in as well as indicate the number of channels the images will be and the size as which to process them. The model we are downloading has a variable size input so we can give it any sized images we want, and it will resize them internally when processing.

# %%
# Define Dataset
data_directory = "/256_ObjectCategories/"
image_size = 32
num_channels = 3
num_classes = 257

# %%
def download(url, directory):
    
    if not os.path.exists(directory):
        os.makedirs(directory)
    filename = url.split('/')[-1]
    filepath = os.path.join(directory, filename)
    if not os.path.exists(filepath):
    
        def _progress(count, block_size, total_size):
            sys.stdout.write('\r>> Downloading %s %.1f%%' %
                           (filename,
                            float(count * block_size) / float(total_size) * 100.0))
            sys.stdout.flush()
    
        filepath, _ = urllib.request.urlretrieve(url,filepath,  _progress)
        print("")
        statinfo = os.stat(filepath)
    else:
        print('File already downloaded')
    tarfile.open(filepath, 'r:gz').extractall(directory)

# %%
download(model_url, model_directory1)
# Out:
# File already downloaded

# %% [markdown]
# ### Map ImageNet Class IDs to Names
# This code takes in the id to name mapping file. We need to processes each line into two separate elements.
# For each line there is an id followed by a tab followed by a class name followed by a newline character. We can simply strip out the newline and separate the elements between the tab to have separated ids and names.
# Gor example: 'n15102894\tknothole\n' -> 'n15102894', 'knothole'

# %%
id_to_name = {}  
    
path = os.path.join(model_directory1, map_id_to_name)
with open(file=path, mode='r') as file:
    #read entire file
    lines = file.readlines()
    for line in lines:
        #strip out new line
        line = line.replace("\n", "")
        #get token strings between tab character
        tokens = line.split("\t")
        #get token ids and names
        uid = tokens[0]
        name = tokens[1]
        #each name is accessed via its id
        id_to_name[uid] = name

# %% [markdown]
# ### Map ImageNet Class IDs to Class values
# This code takes in the id to class value mapping file. Each mapping is formatted in the fashion of entry {target_class: value target_class_string: "stringID"}. The formatting is a little bit messier than the previous mapping so we'll look at each token and try to find target_class and target_class_string and insert the values into a dictionary.

# %%
id_to_class = {}  
class_to_id = {}  

path = os.path.join(model_directory1, map_id_to_class)
with open(file=path, mode='r') as file:
    # read entire file
    lines = file.readlines()

    for line in lines:
        if line.startswith("  target_class: "):
            #split and grad second token as value
            tokens = line.split(": ")
            uclass = int(tokens[1])

        elif line.startswith("  target_class_string: "):
            # get tokens
            tokens = line.split(": ")
            # second token is the string
            uid = tokens[1]
            # strip quotations from token
            uid = uid[1:-2]
            # add to dictionary
            id_to_class[uid] = uclass
            class_to_id[uclass] = uid

# %% [markdown]
# # Build Graph
# With the model downloaded we can build the model in the tensorflow graph. GraphDef() has a simple ParseFromString function we can use to have it build the .pd model file.

# %%
graph = tf.Graph()

with graph.as_default():

    path = os.path.join(model_directory1, map_graph_def)
    with tf.gfile.FastGFile(path, 'rb') as file:
        
        graph_def = tf.GraphDef()
        graph_def.ParseFromString(file.read())

        #remember to set name to empty string else it doesn't work
        tf.import_graph_def(graph_def, name='')

# %% [markdown]
# ## Access Tensors and Enable Session
# Here we get references to tensors that we will needs for various cases. For instance the y_output and y_logits tensors are used to output predictions of the original model. The bottleneck tensors are used for outputting the "bottleneck layer" into a cache, which can then be used as input for a new final classification layer using transfer learning. This will be discussed later

# %%
# Get the output of the Inception model by looking up the tensor
# with the appropriate name for the output of the softmax-classifier.
y_output = graph.get_tensor_by_name(softmax_tensor_name)

# Get the unscaled outputs for the Inception model (aka. softmax-logits).
y_logits = graph.get_tensor_by_name(softmax_tensor_logits_name)

# Get the tensor for the last layer of the graph, aka. the transfer-layer.
bottleneck_layer = graph.get_tensor_by_name(bottleneck_tensor_name)

# Get the number of elements in the transfer-layer.
bottleneck_length = bottleneck_layer.get_shape()[3]

# %% [markdown]
# ## Enable Session to use Graph

# %%
# Create a TensorFlow session for executing the graph.
session = tf.Session(graph=graph)

# %% [markdown]
# ### Classification Helper Functions
# These next three functions are for running classification on the model

# %%
def predictClass(image_path):
    image_data = tf.gfile.FastGFile(image_path, 'rb').read()   

    prediction = session.run(y_output, feed_dict={jpeg_tensor_name: image_data})
    return np.squeeze(prediction)

# %%
def calculateScore(predictions, amount):
    #sorting the predictions
    prediction_args_sorted = predictions.argsort()
    prediction_percent = np.sort(predictions)[:amount:-1]
    topWinners = prediction_args_sorted[::-1]
    i=0
    for winner in topWinners[:amount]:
        uid = class_to_id[winner]
        name = id_to_name[uid].split(",")[0]
        print('%.4f' % prediction_percent[i] + " " + name)
        i+=1

# %%
def classify(image_path, amount, directory = model_directory1):
    image_path = os.path.join(directory, image_path)
    display(Image(image_path))
    calculateScore(predictClass(image_path), amount)

# %% [markdown]
# ## Classify JPEG images
# From here we have enough code to start running predictions on the model. With what we have we can simply take any jpg image and feed it to the model. My example has it predict a few images from the CalTech101Objects dataset.

# %%
classify('cropped_panda.jpg', 5)
# Out:
# 0.8923 giant panda
# 0.0086 indri
# 0.0026 lesser panda
# 0.0014 custard apple
# 0.0011 earthstar

# %% [markdown]
# Now lets have it predict something that it wasn't trained on. In the birds database I've selected an owl. We'll see that it thinkgs it's a sulphur-crested cockatoo, followed by a kite. Obviously this is neither, though it is a bird that flies! Interesting how it thinks its a bird even though it hasn't trained with owls. Now what if you really wanted to classify birds. This large network has a lot of power in it, and can classify some of them, but it doesn't have the classification you exactly want. You have a few things you could do.
#
# You could create your own model that outputs probability of the bird classes you want to test.
# You can just use the model as is with the limited output you care about.
# You can harness the learned features of the larger network, and build a new output layer with your own classes. This is called transfer learning.

# %%
classify('101_ObjectCategories/'+'joshua_tree/image_0001.jpg', amount=5)
# Out:
# 0.1433 valley
# 0.0832 cliff
# 0.0616 volcano
# 0.0534 seashore
# 0.0424 lakeside

# %%
classify('101_ObjectCategories/'+'dolphin/image_0015.jpg', amount=5)
# Out:
# 0.2533 hammerhead
# 0.1744 killer whale
# 0.0844 wig
# 0.0346 velvet
# 0.0264 sea lion

# %%
classify('101_ObjectCategories/'+'pyramid/image_0001.jpg', amount=5)
# Out:
# 0.2880 thatch
# 0.0788 sandbar
# 0.0774 seashore
# 0.0401 Arabian camel
# 0.0352 yawl

# %%
classify('101_ObjectCategories/'+'stegosaurus/image_0001.jpg', amount=2)
# Out:
# 0.9998 triceratops
# 0.0000 sunscreen

# %% [markdown]
# # Transfer Learning

# %%
def bottleneckCache(cache_path, image_paths=None):
    if os.path.exists(cache_path):
    # Load the cached data from the file.
        with open(cache_path, mode='rb') as file:
            bottleneck_values = pickle.load(file)

        print("Data loaded: " + cache_path)
    else:
        # No cache file. Make it.
        num_images = len(image_paths)
        # allocate memory in advance
        bottleneck_values = [None] * num_images

        # For each input image.
        for i in range(num_images):
            bottleneck_values[i] = getBottleneckValues(image_path=os.path.abspath(model_directory1 + data_directory+image_paths[i]))
        
        with open(cache_path, mode='wb') as file:
            pickle.dump(np.array(bottleneck_values), file)

        print("Data saved: " + cache_path)

    return bottleneck_values

# %%
def getBottleneckValues(image_path):
    image_data = tf.gfile.FastGFile(image_path, 'rb').read()
    bottleneck_values = session.run(bottleneck_layer, feed_dict={jpeg_tensor_name: image_data})

    return np.squeeze(bottleneck_values)

# %% [markdown]
# # Set Up data
# Here we're getting all of the images, as well as the classes they belong to.

# %%
def getFiles(dire):
    
    l=[]
    g =[]
    for root, dirs, files in os.walk(dire):
        if dirs:
            names = dirs
        if files:
            r= []
            for name in files:
                r.append(root.split(os.path.sep)[-1] + "/" + name)
                l.append((root.split(os.path.sep)[-1]))
            g.append(r[:])
    return g, names

# %%
output, names = getFiles(os.path.abspath(model_directory1 + data_directory))

# %%
def splitClasses(images, training_amount):
    #expects a list of lists, where the outer represents the class, and inner is the images of the class
    training_data = []
    testing_data = []
    for i in range(len(images)):
        random.shuffle(images[i])
        training_data.append(images[i][:training_amount])
        testing_data.append(images[i][training_amount:])
    return training_data, testing_data

# %% [markdown]
# # Cache images, classes, bottlenecks
# Cache our data so it's easier to run subsequently The first blocks work with the CalTech datasets. The other works with Pascal

# %%
import time
start = time.time()
dataset_folder_name = '256Dataset/'
bottleneck_values = []
if not os.path.exists(dataset_folder_name):
    os.mkdir(dataset_folder_name)
for i in range(len(names)):
    bottleneck_values.append(bottleneckCache(cache_path=os.path.abspath(dataset_folder_name + names[i]+ '.pkl'),image_paths=output[i]))
end = time.time()
# Out:
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\001.ak47.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\002.american-flag.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset
pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\170.rainbow.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\171.refrigerator.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\172.revolver-101.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\173.rifle.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\174.rotary-phone.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\175.roulette-wheel.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\176.saddle.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\177.saturn.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\178.school-bus.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\179.scorpion-101.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\180.screwdriver.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\181.segway.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\182.self-propelled-lawn-mower.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\183.sextant.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\184.sheet-music.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\185.skateboard.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\186.skunk.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\187.skyscraper.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\188.smokestack.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\189.snail.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\190.snake.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\191.sneaker.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\192.snowmobile.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\193.soccer-ball.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\194.socks.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\195.soda-can.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\196.spaghetti.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\197.speed-boat.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\198.spider.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\199.spoon.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\200.stained-glass.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\201.starfish-101.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\202.steering-wheel.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\203.stirrups.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\204.sunflower-101.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\205.superman.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\206.sushi.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\207.swan.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\208.swiss-army-knife.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\209.sword.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\210.syringe.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\211.tambourine.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\212.teapot.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\213.teddy-bear.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\214.teepee.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\215.telephone-box.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\216.tennis-ball.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\217.tennis-court.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\218.tennis-racket.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\219.theodolite.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\220.toaster.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\221.tomato.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\222.tombstone.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\223.top-hat.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\224.touring-bike.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\225.tower-pisa.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\226.traffic-light.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\227.treadmill.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\228.triceratops.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\229.tricycle.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\230.trilobite-101.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\231.tripod.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\232.t-shirt.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\233.tuning-fork.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\234.tweezer.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\235.umbrella-101.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\236.unicorn.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\237.vcr.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\238.video-projector.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\239.washing-machine.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\240.watch-101.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\241.waterfall.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\242.watermelon.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\243.welding-mask.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\244.wheelbarrow.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\245.windmill.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\246.wine-bottle.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\247.xylophone.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\248.yarmulke.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\249.yo-yo.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\250.zebra.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\251.airplanes-101.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\252.car-side-101.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\253.faces-easy-101.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\254.greyhound.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\255.tennis-shoes.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\256.toad.pkl
# Data loaded: C:\Users\sethd\CNNTutorials\5. TransferLearning_Tutorial\256Dataset\257.clutter.pkl

# %%
training_data2, testing_data2 = splitClasses(bottleneck_values, 45)

# %%
#This code takes the 2d lists and flattens them out into 1d. It also generates the label lists
training_data = []
training_labels = []
testing_data = []
testing_labels = []
for i in range(len(training_data2[:])):
    for j in range (len(training_data2[i])):
        training_labels.append(names[i])
        
training_data = [val for sublist in training_data2 for val in sublist]

for i in range(len(testing_data2[:])):
    for j in range (len(testing_data2[i])):
        testing_labels.append(names[i])
        
testing_data = [val for sublist in testing_data2 for val in sublist]

# %%
# zip data
zipped_values = list(zip(training_labels, training_data))

#shuffle the data
random.shuffle(zipped_values)

#unzip new shuffled data
training_labels, training_data = zip(*zipped_values)

# zip data
zipped_values = list(zip(testing_labels, testing_data))

#shuffle the data
random.shuffle(zipped_values)

#unzip new shuffled data
testing_labels, testing_data = zip(*zipped_values)

# %%
# Converts label name to a one hot vector
# eg: if you had classes cat and dog, and an image was the dog, it's label would be [0, 1]
mydict = {}
i=0
for name in names:
    mydict[name] = i
    i += 1
def labelNamesToValues(labels):
    list_of_labels = []
    one_hot_labels = [0] * len(mydict.values())
    for label in labels:
        new_list = one_hot_labels[:]
        new_list[mydict[label]] = 1
        list_of_labels.append(new_list)
        
    return list_of_labels

# %%
train_labels = labelNamesToValues(training_labels)
test_labels = labelNamesToValues(testing_labels)

# %% [markdown]
# For fun you can print out what the bottleneck values look like

# %% [markdown]
# # Create new Classification Layer

# %%
num_epochs = 300

# %%
with graph.as_default():
    
    x_input = tf.placeholder(tf.float32, shape=[None, bottleneck_length])
    y_output = tf.placeholder(tf.float32, shape=[None, num_classes])
    y_output_class = tf.argmax(y_output, dimension=1)
    
    num_epochs=500
    batch_size = 128
    
    global_step = tf.Variable(0, trainable=False)
    #learning rate
    learning_rate = tf.train.exponential_decay(.01, global_step, num_epochs, 0.90, staircase = True)
    learning_rate = 0.1
    #fully connected layer
    with tf.variable_scope('newfc'):
        weights = tf.get_variable('weights', shape=[bottleneck_length, num_classes],
                                 initializer = tf.contrib.layers.xavier_initializer())
        biases = tf.get_variable('biases', shape=[num_classes], initializer=tf.constant_initializer(0))

        matrix_multiply = tf.matmul(x_input, weights)

        y_out = tf.nn.bias_add(matrix_multiply, biases)
        
    y_class = tf.nn.softmax(logits=y_out)
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=y_output, logits=y_out)
    cross_entropy_mean = tf.reduce_mean(cross_entropy)

    correct_prediction = tf.equal(tf.argmax(y_out,1), tf.argmax(y_output,1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    #optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cross_entropy_mean, global_step = global_step)
    #optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy_mean)
    optimizer = tf.train.MomentumOptimizer(learning_rate, 0.9).minimize(cross_entropy_mean)

# %%
num_epochs = 300

# %%
model_name = "Caltch256-45-3-2"
model_filename = model_name + "100epochsModel.ckpt"
model_directory2 = os.getcwd() + "/Models/" + model_name
model_path = model_directory2 + "/" + model_filename

# %%
def getTime(seconds):
    m, s = divmod(seconds, 60)
    h, m = divmod(m, 60)
    
    return h, m, s

# %%
def batch(x_data,y_data=None, batches=1):
    length = len(x_data)
    
    # return iterations
    for index in range(0, length, batches):
        if y_data is None:
            yield x_data[index:min(index + batches, length)]
        else:
            yield x_data[index:min(index + batches, length)], y_data[index:min(index + batches, length)]

# %%
start = time.time()
train_accuracy_list = []
valid_accuracy_list = []
train_loss_list = []
valid_loss_list = []
time_list = []
epoch_list = []

print("TRAINING ")

with tf.Session(graph = graph) as session:
    session.run(tf.global_variables_initializer())
    saver = tf.train.Saver()
    #if os.path.exists(model_directory2):
        #print("Loading model...")
        #load_path = saver.restore(session, model_path)
    for current_epoch in range(200):
        for x, y in batch(training_data, train_labels, batch_size):
            feed_dict = {x_input: x, y_output: y}
            # training and optimizing
            session.run([optimizer], feed_dict = feed_dict)

        train_accuracy = accuracy.eval(feed_dict={x_input:training_data, y_output: train_labels})
        train_accuracy_list.append(train_accuracy)
        valid_accuracy = accuracy.eval(feed_dict={x_input:testing_data, y_output: test_labels})
        valid_accuracy_list.append(valid_accuracy)
        train_loss = cross_entropy_mean.eval(feed_dict={x_input:training_data, y_output: train_labels})
        train_loss_list.append(train_loss)
        valid_loss = cross_entropy_mean.eval(feed_dict={x_input:testing_data, y_output: test_labels})
        valid_loss_list.append(valid_loss)
        
        current_time = time.time() - start
        hours, minutes, seconds = getTime(current_time)
        print("Epoch[%d]" % current_epoch + "%d" % hours + ":%2d" % minutes + ":%2d " % seconds + "%f " % train_accuracy + " %f" % valid_accuracy + " %f " % train_loss + " %f" % valid_loss)
        time_list.append(current_time)
        epoch_list.append(current_epoch)
        # Evaluate on test dataset.
    if not os.path.exists(model_directory2):
        os.mkdir(model_directory2)
    save_path = saver.save(session, model_path)
# Out:
# TRAINING
# Epoch[0]0: 0: 3 0.933679  0.795714 0.351813  0.963941
# Epoch[1]0: 0: 5 0.978729  0.831530 0.151416  0.753544
# Epoch[2]0: 0: 7 0.990921  0.842401 0.091944  0.700492
# Epoch[3]0: 0:10 0.995936  0.847652 0.062411  0.675926
# Epoch[4]0: 0:12 0.998097  0.851801 0.045915  0.654428
# Epoch[5]0: 0:14 0.999135  0.853692 0.036138  0.639434
# Epoch[6]0: 0:17 0.999221  0.855109 0.029927  0.631745
# Epoch[7]0: 0:19 0.999654  0.855477 0.025619  0.627709
# Epoch[8]0: 0:21 0.999827  0.855162 0.022433  0.625174
# Epoch[9]0: 0:24 0.999827  0.854742 0.019980  0.623372
# Epoch[10]0: 0:26 0.999913  0.855635 0.018032  0.622005
# Epoch[11]0: 0:28 1.000000  0.855319 0.016449  0.620945
# Epoch[12]0: 0:31 1.000000  0.855425 0.015138  0.620125
# Epoch[13]0: 0:33 1.000000  0.855582 0.014035  0.619504
# Epoch[14]0: 0:35 1.000000  0.854847 0.013093  0.619048
# Epoch[15]0: 0:38 1.000000  0.854794 0.012280  0.618725
# Epoch[16]0: 0:40 1.000000  0.854847 0.011569  0.618511
# Epoch[17]0: 0:42 1.000000  0.854479 0.010941  0.618385
# Epoch[18]0: 0:45 1.000000  0.854742 0.010382  0.618329
# Epoch[19]0: 0:47 1.000000  0.854847 0.009881  0.618332
# Epoch[20]0: 0:49 1.000000  0.855109 0.009428  0.618381
# Epoch[21]0: 0:52 1.000000  0.855057 0.009017  0.618468
# Epoch[22]0: 0:54 1.000000  0.854742 0.008642  0.618588
# Epoch[23]0: 0:56 1.000000  0.854637 0.008298  0.618733
# Epoch[24]0: 0:59 1.000000  0.854689 0.007982  0.618901
# Epoch[25]0: 1: 1 1.000000  0.854742 0.007690  0.619086
# Epoch[26]0: 1: 4 1.000000  0.855004 0.007419  0.619287
# Epoch[27]0: 1: 6 1.000000  0.855425 0.007167  0.619500
# Epoch[28]0: 1: 8 1.000000  0.855477 0.006933  0.619723
# Epoch[29]0: 1:11 1.000000  0.855477 0.006714  0.619956
# Epoch[30]0: 1:13 1.000000  0.855372 0.006509  0.620195
# Epoch[31]0: 1:15 1.000000  0.855319 0.006316  0.620441
# Epoch[32]0: 1:18 1.000000  0.855425 0.006135  0.620691
# Epoch[33]0: 1:20 1.000000  0.855425 0.005964  0.620946
# Epoch[34]0: 1:22 1.000000  0.855162 0.005803  0.621204
# Epoch[35]0: 1:25 1.000000  0.855109 0.005651  0.621465
# Epoch[36]0: 1:27 1.000000  0.855214 0.005506  0.621728
# Epoch[37]0: 1:29 1.000000  0.855109 0.005369  0.621992
# Epoch[38]0: 1:32 1.000000  0.855319 0.005239  0.622258
# Epoch[39]0: 1:34 1.000000  0.855372 0.005115  0.622525
# Epoch[40]0: 1:36 1.000000  0.855372 0.004997  0.622792
# Epoch[41]0: 1:39 1.000000  0.855477 0.004885  0.623060
# Epoch[42]0: 1:41 1.000000  0.855477 0.004778  0.623327
# Epoch[173]0: 6:49 1.000000  0.857578 0.001266  0.648543
# Epoch[174]0: 6:51 1.000000  0.857578 0.001259  0.648678
# Epoch[175]0: 6:54 1.000000  0.857578 0.001252  0.648812
# Epoch[176]0: 6:56 1.000000  0.857578 0.001245  0.648946
# Epoch[177]0: 6:58 1.000000  0.857578 0.001239  0.649079
# Epoch[178]0: 7: 1 1.000000  0.857578 0.001232  0.649212
# Epoch[179]0: 7: 3 1.000000  0.857578 0.001225  0.649344
# Epoch[180]0: 7: 5 1.000000  0.857578 0.001219  0.649476
# Epoch[181]0: 7: 8 1.000000  0.857578 0.001213  0.649607
# Epoch[182]0: 7:10 1.000000  0.857578 0.001206  0.649737
# Epoch[183]0: 7:12 1.000000  0.857578 0.001200  0.649867
# Epoch[184]0: 7:15 1.000000  0.857578 0.001194  0.649997
# Epoch[185]0: 7:17 1.000000  0.857578 0.001188  0.650126
# Epoch[186]0: 7:19 1.000000  0.857578 0.001181  0.650254
# Epoch[187]0: 7:22 1.000000  0.857578 0.001175  0.650383
# Epoch[188]0: 7:24 1.000000  0.857578 0.001169  0.650510
# Epoch[189]0: 7:27 1.000000  0.857630 0.001164  0.650637
# Epoch[190]0: 7:29 1.000000  0.857630 0.001158  0.650764
# Epoch[191]0: 7:31 1.000000  0.857630 0.001152  0.650890
# Epoch[192]0: 7:34 1.000000  0.857630 0.001146  0.651015
# Epoch[193]0: 7:36 1.000000  0.857630 0.001140  0.651141
# Epoch[194]0: 7:38 1.000000  0.857630 0.001135  0.651265
# Epoch[195]0: 7:41 1.000000  0.857735 0.001129  0.651389
# Epoch[196]0: 7:43 1.000000  0.857735 0.001124  0.651513
# Epoch[197]0: 7:45 1.000000  0.857683 0.001118  0.651636
# Epoch[198]0: 7:48 1.000000  0.857683 0.001113  0.651759
# Epoch[199]0: 7:50 1.000000  0.857683 0.001108  0.651881

# %% [markdown]
# ### Reload the session and run predictions
# Here we want to load the model and session, and get predictions. In this case I'm getting the entire validation set.

# %%
with tf.Session(graph = graph) as session:
    tf.global_variables_initializer()
    saver = tf.train.Saver()
    load_path = saver.restore(session, model_path)
    [p] = session.run([y_class], feed_dict={x_input: testing_data})
import pandas as pd

# Create a Pandas dataframe from some data.
df = pd.DataFrame({'Epoch': epoch_list, 'Time': time_list, 'TrainAcc': train_accuracy_list, 'ValidAcc' : valid_accuracy_list, 'TrainLoss': train_loss_list, 'ValidLoss' : valid_loss_list})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter(model_path + 'Loss.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# # Classify single Images with top x accuracy

# %%
with tf.Session(graph = graph) as session:
    tf.global_variables_initializer()
    load_path = saver.restore(session, model_path)
    [p] = session.run([y_class], feed_dict={x_input: x_test})
    #image = getBottleneckValues('keyboard.jpg')

# %%
def predictClass2(bottleneck):   
    prediction = session.run(y_class, feed_dict={x_input: bottleneck})
    return np.squeeze(prediction)

# %%
def calculateScore2(predictions, amount):
    #sorting the predictions
    prediction_args_sorted = predictions.argsort()
    prediction_percent = np.sort(predictions)[:amount:-1]
    topWinners = prediction_args_sorted[::-1]
    i=0
    for winner in topWinners[:amount]:
        name = label_names[winner]
        print('%.4f' % prediction_percent[i] + " " + name)
        i+=1

# %%
def classify2(image_path, bottleneck, amount = 1, directory=model_directory1):
    image_path = os.path.join(directory, image_path)
    display(Image(image_path))
    calculateScore2(predictClass2(bottleneck), amount)

# %%
i = 109

with tf.Session(graph = graph) as session:
    tf.global_variables_initializer()
    load_path = saver.restore(session, model_path)
    classify2('keyboard.jpg', np.reshape(image, [1, 2048]), amount=5)
# Out:
# 0.6963 045.computer-keyboard
# 0.0524 127.laptop-101
# 0.0168 257.clutter
# 0.0089 027.calculator
# 0.0069 046.computer-monitor

# %%
def getTopAccuracy(predictions, labels, amount):
    correct_predictions = 0
    for i in range(len(predictions)):
        pred = predictions[i]
        #sorting the predictions
        prediction_args_sorted = pred.argsort()
        prediction_percent = np.sort(pred)[:amount:-1]
        topWinners = prediction_args_sorted[::-1]
        for winner in topWinners[:amount]:
            name = label_names[winner]
            if label_names[np.argmax(labels[i])] == name:
                correct_predictions = correct_predictions +1
                
    return correct_predictions / len(predictions)

# %%
getTopAccuracy(p, y_test, 5)
# Out:
# 0.9590443686006825

# %%
def plotPredictions(images, labels, predictions=None, filename=None):
    fig, axes = plt.subplots(3, 3, figsize=(15,15));
    
    for i, ax in enumerate(axes.flat):
        # Interpolation type.

        # Plot image.
        ax.imshow(img[i])
        ax.grid(False)    
        # Show true and predicted classes.
        
        #replace with title?
        if predictions is None:
            xlabel = "Label: {0}".format(labels[i])
        else:

            xlabel = "Label: {0}\nPrediction: {1}".format(label_names[labels[i]], label_names[predictions[i]])

        # Show the classes as the label on the x-axis.
        ax.set_xlabel(xlabel)
        
        # Remove ticks from the plot.
        ax.set_xticks([])
        ax.set_yticks([])
    if filename is not None:
        print("bananas")
        plt.savefig(filename)

# %% [markdown]
# # Make Predictions

# %%
with tf.Session(graph = graph) as session:
    tf.global_variables_initializer()
    load_path = saver.restore(session, model_path)
    prediction = session.run(y_class, feed_dict={x_input: x_test})
    print("Test Accuracy: " + str(accuracy.eval(feed_dict={x_input:x_test, y_output: y_test})))
    print("Test Loss: " + str(cross_entropy_mean.eval(feed_dict={x_input:x_test, y_output: y_test})))
predictions = []

for pred in prediction:
    predictions.append(pred.argmax())
    predictions_true = []

for pred in y_test:
    pred = np.asarray(pred)
    predictions_true.append(pred.argmax())
    
actual_images = z_test_images
# Out:
# Test Accuracy: 0.883959
# Test Loss: 1.31482

# %%
index = 44

img = []
for i in range(index,index+9):
    img.append(mpimg.imread(os.path.abspath(model_directory1 + data_directory + actual_images[i])));
    
labels = predictions_true[index:index+9];
preds = predictions[index:index+9]



plotPredictions(img, labels, preds, 'flowersmom.jpg')
# Out:
# bananas

# %%
def plotConfusionMatrix(labels, predictions, title_name, file_name):
           
    conf_mat = confusion_matrix(predictions_true, predictions)
    df_cm = pd.DataFrame(conf_mat, index = [i for i in label_names], columns = [i for i in label_names])
    plt.figure(figsize = (15,15))
    sn.set(font_scale=1.4)#for label size
    sn.heatmap(df_cm, annot=True,annot_kws={"size": 16})# font size
    plt.title(title_name)
    plt.savefig(file_name)

# %%
plotConfusionMatrix(predictions_true, predictions, 'Flowers Dataset Confusion Matrix','flower_test.jpg')
